# %% [markdown]
# <a href="https://colab.research.google.com/github/Srijon2107/FifaDataAnalysis/blob/main/FIFA_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2a2edeaf-b6de-466c-a87f-6a487d5a1d98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a2edeaf-b6de-466c-a87f-6a487d5a1d98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fifa_list=pd.read_csv('Fifa 23 Players Data.csv')
fifa_list
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %%
fifa_list.head(500)
# Out:
#            Known As                  Full Name  Overall  Potential  \
# 0          L. Messi               Lionel Messi       91         91
# 1        K. Benzema              Karim Benzema       91         91
# 2    R. Lewandowski         Robert Lewandowski       91         91
# 3      K. De Bruyne            Kevin De Bruyne       91         91
# 4         K. Mbappé              Kylian Mbappé       91         95
# ..              ...                        ...      ...        ...
# 495            Fred  Frederico de Paula Santos       80         80
# 496       C. Günter           Christian Günter       80         80
# 497       A. Rabiot              Adrien Rabiot       80         81
# 498       Rui Silva  Rui Tiago Dantas da Silva       80         82
# 499    A. Romagnoli          Alessio Romagnoli       80         80
#
#      Value(in Euro) Positions Played Best Position Nationality  \
# 0          54000000               RW           CAM   Argentina
# ...

# %%
fifa_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     18539 non-null  object
#  1   Full Name                    18539 non-null  object
#  2   Overall                      18539 non-null  int64
#  3   Potential                    18539 non-null  int64
#  4   Value(in Euro)               18539 non-null  int64
#  5   Positions Played             18539 non-null  object
#  6   Best Position                18539 non-null  object
#  7   Nationality                  18539 non-null  object
#  8   Image Link                   18539 non-null  object
#  9   Age                          18539 non-null  int64
#  10  Height(in cm)                18539 non-null  int64
#  11  Weight(in kg)                18539 non-null  int64
#  12  TotalStats                   18539 non-null  int64
# ...

# %%
fifa_list.describe()
# Out:
#             Overall     Potential  Value(in Euro)           Age  \
# count  18539.000000  18539.000000    1.853900e+04  18539.000000
# mean      65.852042     71.016668    2.875461e+06     25.240412
# std        6.788353      6.192866    7.635129e+06      4.718163
# min       47.000000     48.000000    0.000000e+00     16.000000
# 25%       62.000000     67.000000    4.750000e+05     21.000000
# 50%       66.000000     71.000000    1.000000e+06     25.000000
# 75%       70.000000     75.000000    2.000000e+06     29.000000
# max       91.000000     95.000000    1.905000e+08     44.000000
#
#        Height(in cm)  Weight(in kg)    TotalStats     BaseStats  \
# count   18539.000000   18539.000000  18539.000000  18539.000000
# mean      181.550839      75.173904   1602.114569    357.946221
# std         6.858097       7.013593    273.160237     39.628259
# min       155.000000      49.000000    759.000000    224.000000
# 25%       177.000000      70.000000   1470.000000    331.000000
# ...

# %%
fifa_list.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
fifa_list.index
# Out:
# RangeIndex(start=0, stop=18539, step=1)

# %%
ind=fifa_list['Height(in cm)']
ind
# Out:
# 0        169
# 1        185
# 2        185
# 3        181
# 4        182
#         ...
# 18534    174
# 18535    175
# 18536    170
# 18537    178
# 18538    176
# Name: Height(in cm), Length: 18539, dtype: int64

# %%
overall_grt_87=fifa_list[fifa_list['Overall']>87]
overall_grt_87
# Out:
#              Known As                          Full Name  Overall  Potential  \
# 0            L. Messi                       Lionel Messi       91         91
# 1          K. Benzema                      Karim Benzema       91         91
# 2      R. Lewandowski                 Robert Lewandowski       91         91
# 3        K. De Bruyne                    Kevin De Bruyne       91         91
# 4           K. Mbappé                      Kylian Mbappé       91         95
# 5            M. Salah                      Mohamed Salah       90         90
# 6         T. Courtois                   Thibaut Courtois       90         91
# 7            M. Neuer                       Manuel Neuer       90         90
# 8   Cristiano Ronaldo       C. Ronaldo dos Santos Aveiro       90         90
# 9         V. van Dijk                    Virgil van Dijk       90         90
# 10            H. Kane                         Harry Kane       89         89
# ...

# %%
wage_st_list=fifa_list[(fifa_list['Wage(in Euro)']>20000)|(fifa_list['Best Position']=='ST')]
wage_st_list
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18495     Feng Zeyuan         Zeyuan Feng       48         58          100000
# 18502        Wei Feng            Feng Wei       48         61          110000
# 18513   Shan Huanhuan       Huanhuan Shan       48         57          100000
# 18527     Liu Junxian         Junxian Liu       48         58          110000
# 18532        H. Singh   Harmanpreet Singh       48         56          100000
#
# ...

# %%
fifa_list['transfer fee']=fifa_list['Wage(in Euro)']+fifa_list['Release Clause']
fifa_list
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %%
fifa_list['fee_per_age']=fifa_list['transfer fee']/fifa_list['Age']
fifa_list
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %%
fifa_list.iloc[1500:1800]
# Out:
#              Known As                       Full Name  Overall  Potential  \
# 1500        A. Gordon                  Anthony Gordon       75         84
# 1501        B. Mbeumo                    Bryan Mbeumo       75         81
# 1502        L. Openda                     Loïs Openda       75         83
# 1503          Y. Adli                     Yacine Adli       75         82
# 1504        D. Spence                     Djed Spence       75         84
# ...               ...                             ...      ...        ...
# 1795       E. Pinnock                   Ethan Pinnock       75         75
# 1796  B. Martins Indi              Bruno Martins Indi       75         75
# 1797          D. Ward                      Danny Ward       75         75
# 1798        R. Thomas                   Romain Thomas       75         75
# 1799  Rafael Cachoira  Rafael Jorgino Cachoira Rebelo       75         75
#
#       Value(in Euro) Positions Played Best Position  Nationality  \
# ...

# %%
fifa_list.ind=fifa_list.sort_values('Defending Total',ascending=False)
fifa_list.ind
# Out:
#               Known As                     Full Name  Overall  Potential  \
# 9          V. van Dijk               Virgil van Dijk       90         90
# 25          Marquinhos            Marcos Aoás Corrêa       88         90
# 20          Rúben Dias  Rúben Santos Gato Alves Dias       88         91
# 40        K. Koulibaly             Kalidou Koulibaly       87         87
# 60         M. Škriniar                Milan Škriniar       86         87
# ...                ...                           ...      ...        ...
# 17838       M. Stjopin                Maksim Stjopin       53         68
# 18159    M. Bortniczuk             Maciej Bortniczuk       52         66
# 18123     G. Cowmeadow              George Cowmeadow       52         63
# 10359         A. Pears                 Aynsley Pears       65         72
# 18525  J. Russell-Rowe            Jacen Russell-Rowe       48         65
#
#        Value(in Euro) Positions Played Best Position  Nationality  \
# ...

# %%
high_dribble=fifa_list[fifa_list['Dribbling']>80]
high_dribble
# Out:
#              Known As               Full Name  Overall  Potential  \
# 0            L. Messi            Lionel Messi       91         91
# 1          K. Benzema           Karim Benzema       91         91
# 2      R. Lewandowski      Robert Lewandowski       91         91
# 3        K. De Bruyne         Kevin De Bruyne       91         91
# 4           K. Mbappé           Kylian Mbappé       91         95
# ...               ...                     ...      ...        ...
# 3993  Gerard Valentín  Gerard Valentín Sancho       71         71
# 4403     Lee Dong Jun            Dong Jun Lee       70         73
# 5069           M. Cho         Mohamed-Ali Cho       70         85
# 6740       M. Ramírez          Matías Ramírez       68         77
# 8181     F. El Melali         Farid El Melali       67         70
#
#       Value(in Euro) Positions Played Best Position     Nationality  \
# 0           54000000               RW           CAM       Argentina
# ...

# %%
high_dribble_sort=high_dribble.sort_values('Overall',ascending=False)
high_dribble_sort
# Out:
#              Known As               Full Name  Overall  Potential  \
# 0            L. Messi            Lionel Messi       91         91
# 2      R. Lewandowski      Robert Lewandowski       91         91
# 3        K. De Bruyne         Kevin De Bruyne       91         91
# 4           K. Mbappé           Kylian Mbappé       91         95
# 1          K. Benzema           Karim Benzema       91         91
# ...               ...                     ...      ...        ...
# 3993  Gerard Valentín  Gerard Valentín Sancho       71         71
# 4403     Lee Dong Jun            Dong Jun Lee       70         73
# 5069           M. Cho         Mohamed-Ali Cho       70         85
# 6740       M. Ramírez          Matías Ramírez       68         77
# 8181     F. El Melali         Farid El Melali       67         70
#
#       Value(in Euro) Positions Played Best Position     Nationality  \
# 0           54000000               RW           CAM       Argentina
# ...

# %%
age = np.array([67,81,81,70,73,71,96,93])
height = np.array([169,185,185,181,182,175,199,193])

print(age)
print(height)
# Out:
# [67 81 81 70 73 71 96 93]
# [169 185 185 181 182 175 199 193]

# %%
#slice array
print(height[1:5])
# Out:
# [185 185 181 182]

# %%
#concatinate
arr = np.concatenate((age, height))
print(arr)
# Out:
# [ 67  81  81  70  73  71  96  93 169 185 185 181 182 175 199 193]

# %%
#split
newarr = np.array_split(height, 3)
print(newarr)
# Out:
# [array([169, 185, 185]), array([181, 182, 175]), array([199, 193])]

# %%
print(age.dtype)

#add two elements
print(age[2] + age[3])
# Out:
# int64
# 151

# %%
#sort
print(np.sort(height))
# Out:
# [169 175 181 182 185 185 193 199]

# %%
#adding two array
newarr = np.add(height, age)
print(newarr)
# Out:
# [236 266 266 251 255 246 295 286]
# [102 104 104 111 109 104 103 100]
# 1423896002948160

# %%
#subtracting two array
newarr = np.subtract(height, age)
print(newarr)
# Out:
# [102 104 104 111 109 104 103 100]

# %%
#product
x = np.prod(age)
print(x)
# Out:
# 1423896002948160

# %%
from numpy import random
x = random.choice([ 5, 7, 9], p=[ 0.3, 0.6,0.1], size=(100))

print(x)
# Out:
# [5 9 5 7 5 5 7 5 7 7 7 7 7 5 5 5 5 7 5 7 5 7 7 7 7 5 7 5 7 5 9 7 7 7 7 7 9
#  5 7 7 9 7 9 7 5 7 9 7 7 5 5 7 5 5 5 7 9 5 7 7 5 5 5 5 7 5 7 9 7 7 7 7 7 5
#  5 7 7 5 7 5 5 9 7 7 7 7 5 5 7 7 7 5 5 7 7 5 7 7 5 5]

# %%
age=np.array(['31','33','34','35'])
name=np.array(['K.De Bruyne','R. Lewandowski','K.Benzeme','L.Messi'])
plt.plot(name,age,linestyle = 'dashed')
plt.title("name vs age")
plt.xlabel("age")
plt.ylabel("name")
plt.show()

# %%
x = np.array(['L.Messi','K.Benzeme','R. Lewandowski','K.De Bruyne'])
y = np.array([54000000, 64000000, 84000000,107500000])

plt.plot(x, y,marker='*')

plt.xlabel("names")
plt.ylabel("values")

plt.show()

# %%
plt.plot(x, y)
plt.xlabel("names")
plt.ylabel("values")

plt.grid()

plt.show()

# %%
name = np.array(['L. Messi','Neymar Jr','H. Son','Casemiro','Ederson'])
Totalstats = np.array([2190,2157,2141,2209,1583])
plt.xlabel("names")
plt.ylabel("TotalStats")
plt.scatter(name,Totalstats)
plt.show()

# %%
names=(['L. Messi','M. Salah','J. Kimmich','Marquinhos','M. ter Stegen'])
Wage=(['195000','270000','130000','170000','210000'])
sizes = np.array([20,50,100,200,500])
plt.scatter(x, y, s=sizes, alpha=0.5)
plt.xlabel("names")
plt.ylabel("wage(in euro)")

plt.show()

# %%
names=(['L. Messi','M. Salah','J. Kimmich','Marquinhos','M. ter Stegen'])
Wage=(['195000','270000','130000','170000','210000'])
plt.barh(names,Wage,height = 0.5)
plt.xlabel("names")
plt.ylabel("wage(in euro)")
plt.show()

# %%
name=np.array(['L. Messi','Cristiano Ronaldo','V. van Dijk','H. Kane','T. Courtois'])
base_stats=np.array(['452','445','461','453','473'])
plt.pie(base_stats, labels= name)
plt.legend(title = "players:")
plt.show()

# %%
name=np.array(['L. Messi','Cristiano Ronaldo','V. van Dijk','H. Kane','T. Courtois'])
base=np.array(['452','445','461','453','473'])
myexplode = [0.0, 0.2, 0.0, 0.0,0.0]
plt.pie(base, labels = name,explode = myexplode, shadow = True)
plt.show()

# %%
fifa_data = {'name': ['L. Messi','Cristiano Ronaldo','V. van Dijk','H. Kane','T. Courtois'],
          'base': [452,445,461,453,473]}
fifa_df = pd.DataFrame(fifa_data)  # data frame
sns.scatterplot(data=fifa_df , x = 'name' , y = 'base')
# Out:
# <Axes: xlabel='name', ylabel='base'>

# %%
fifa_data = {'age': [31,33,34,35,32],
          'base': [452,445,461,453,473]}
fifa_df = pd.DataFrame(fifa_data)
sns.pairplot(data=fifa_df, diag_kind="kde", height=3)

# %%
sns.pairplot(data =fifa_df,kind="kde", diag_kws= {'color':'gray'})

# %%
fifa_data={'name' :['L. Messi','Neymar Jr','H. Son','Casemiro','Ederson'],
'Totalstats' : [2190,2157,2141,2209,1583]}
fifa_df = pd.DataFrame(fifa_data)
sns.barplot(data=fifa_df, x='name', y='Totalstats' )
# Out:
# <Axes: xlabel='name', ylabel='Totalstats'>

# %%
sns.histplot(data=fifa_df, x='name', y='Totalstats')
plt.show()

# %%
sns.boxplot(data=fifa_df, x='name', y='Totalstats')
plt.show()

# %%
sns.violinplot(data=fifa_df, x='name', y='Totalstats', fill=False)
plt.show()

# %%
fifa_data = {'name': ['L. Messi','Cristiano Ronaldo','V. van Dijk','H. Kane','T. Courtois'],
          'base': [452,445,461,453,473]}
fifa_df = pd.DataFrame(fifa_data)  # data frame
sns.barplot(data=fifa_df , x = 'name' , y = 'base')
# Out:
# <Axes: xlabel='name', ylabel='base'>
